# %%
## TIC TAC TOE That hates player 2## 
p1l = set()
p2l = set()
while True: 
    p1 = input('Player 1. Pick a space on the board between 1 and 9')
    p1l.add(p1)
    print (p1)
    print (p1l)
    if p1l == {'1','2','3'}: 
        print ('YOU WIN P1. Nice.')
        break
    if p1l == {'4','5','6'}:
        print ('PLAYER 1 WINS. Have a you day.')
        break
    elif p1l == {'7','8','9'}:
        print ('PLAYER 1 WINS. Everyone loves you.')
        break
    elif p1l == {'1','4','7'}:
        print ('PLAYER 1 WINS. That is what you did.')
        break
    elif p1l == {'2','5','8'}:
        print ('PLAYER 1 WINS. Not loser!')
        break
    elif p1l == {'3','6','9'}:
        print ('PLAYER 1 WINS. Sweet.')
        break
    elif p1l == {'3','6','9'}:
        print ('PLAYER 1 WINS. Sweet.')
        break
    elif p1l == {'1','5','9'}:
        print ('PLAYER 1 WINS. Get some ice cream.')
        break
    elif p1l == {'7','5','3'}:
        print ('PLAYER 1 WINS. Great.')
        break
    p2 = input('Player 2. Pick a space from board between 1 and 9')
    p2l.add(p2)
    print (p2)
    print (p2l)
    if p2l == {'1','2','3'}: 
        print ('YOU WIN P2. Whatever.')
        break
    if p2l == {'4','5','6'}:
        print ('PLAYER 2 WINS. Fine.')
        break
    elif p2l == {'7','8','9'}:
        print ('PLAYER 2 WINS. Sandwiches?')
        break
    elif p2l == {'1','4','7'}:
        print ('PLAYER 2 WINS. Good for you.')
        break
    elif p2l == {'2','5','8'}:
        print ('PLAYER 2 WINS. You should have lost.')
        break
    elif p2l == {'3','6','9'}:
        print ('PLAYER 2 WINS. .')
        break
    elif p2l == {'3','6','9'}:
        print ('PLAYER 2 WINS. .')
        break
    elif p2l == {'1','5','9'}:
        print ('PLAYER 2 WINS. You owe me five dollars.')
        break
    elif p2l == {'7','5','3'}:
        print ("PLAYER 2 WINS. They said it couldn't be done. Our expectations couldn't be lower for player2. Here's to change *opens beer*.")
        break
